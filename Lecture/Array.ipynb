# %% [markdown]
# # 배열
# ---
# ### 배열의 선언 형식
# ```
#  int arr[];
#
#  arr = new int[3];
# ```
#
# 참조변수인 int형 배열을 선언
#
#
#
# - 저장공간의 크기는 int이고 개수는 3개로 메모리를 할당하게 됨.
#  즉 크기는 4byte(int형의 크기)이고 3개의 연속된 메모리 공간을 할당함.
#  >메모리는 다음과 같이 {4byte},{4byte},{4byte} int인 3개의 변수를 연속되게 할당됨.
#
#  arr는 값을 직접 저장하는게 아니라,
#  위의 { },{ },{ }의 메모리 주소를 가르키게 됨.
#
#
#
# - arr의 주소 : ex) 50
#   arr의 값   :     100 (배열원소의 시작 주소100을 저장 )
#   arr : 100
#  -->{----}---{----}---{----}
#  -------------- 100----104----108
#  -------------- arr+0--arr+1--arr+2
#  -------------- arr[0]--arr[1]--arr[2]
#  위 3가지 수식은 해당 메모리 주소를 접근하는 방법이다. 표기만 다를 뿐!
#
#  첫 번째 {4byte}의 메모리 주소가 100이라고 하면
#  두 번째 {4byte}의 메모리 주소는 104
#  세 번째는 108이 된다.
#
#  이 후 각 메모리에 값을 저장하기 위해서는
#  해당 배열 인덱스의 주소를 접근하면 된다.
#
#  arr[0], arr[1], arr[2] 처럼,
#  arr뒤에 있는 괄호와 숫자로 해당 주소를 가르키고, 값을 저장하거나 불러올 수 있다.
#  [정수]를 arr의 인덱스 라고 한다.
#
#
#  # 배열과 객체
#  ---
# 이번엔 배열을 예를 들어 객체에 대한 이해를 해보자.
# ```
# public static void main(String[] args) {
#     int a [] = new int [2];
#     int b [];
#     a = array(a);
#     b = array2(a);
#
#     for(int i = 0; i < a.lenght; i++){
#         System.out.println(a);
#     }
#     for(int i = 0; i < b.lenght; i++){
#         System.out.println(b);
#     }
# }
# static int[] array(int arr [] ){
#     arr[0] = 1;
#     arr[1] = 2;
#     return arr;
# }
# static int[] array2(int num[]){
#     num[0] = 3;
#     num[1] = 4;
#     return num;
#
# }
#
# ```
# 결과 값을 예측해 보자.
# 어떻게 나올것이라 예측하는가?
#
# 정답은
# 3
# 4
# 3
# 4
# 이다.
#
# 왜 b와 a가 값이 서로 같을 까?
# 자 두 메소드 array와 array2는 매개변수 값을 a로 받았다.
# a는 배열로 **객체**이다.
# a = array(a)의 결과는
# a[0] = 1
# a[1] = 2  값이 저장된다. 이후
#
# b = array2(a)가 실행되고 결과는 다음과 같다.
